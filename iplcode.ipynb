# %%
import pandas as pd
import numpy as np

# %%
urls_dict = {
    "result_summary": "https://www.espncricinfo.com/records/trophy/team-results-summary/indian-premier-league-117",
    "highest_totals": "https://www.espncricinfo.com/records/trophy/team-highest-innings-totals/indian-premier-league-117",
    "lowest_totals": "https://www.espncricinfo.com/records/trophy/team-lowest-innings-totals/indian-premier-league-117",

    "most_runs": "https://www.espncricinfo.com/records/trophy/batting-most-runs-career/indian-premier-league-117",
    "high_scores": "https://www.espncricinfo.com/records/trophy/batting-most-runs-innings/indian-premier-league-117",
    "most_sixes": "https://www.espncricinfo.com/records/trophy/batting-most-sixes-career/indian-premier-league-117",
    "most_fifties": "https://www.espncricinfo.com/records/trophy/batting-most-fifties-career/indian-premier-league-117",
    "most_ducks": "https://www.espncricinfo.com/records/trophy/batting-most-ducks-career/indian-premier-league-117",

    "most_wickets": "https://www.espncricinfo.com/records/trophy/bowling-most-wickets-career/indian-premier-league-117",
    "best_bowling_figures": "https://www.espncricinfo.com/records/trophy/bowling-best-figures-innings/indian-premier-league-117",
    "best_economy_rates": "https://www.espncricinfo.com/records/trophy/bowling-best-career-economy-rate/indian-premier-league-117",
    "best_strike_rates": "https://www.espncricinfo.com/records/trophy/bowling-best-career-strike-rate/indian-premier-league-117",

    "most_catches": "https://www.espncricinfo.com/records/trophy/fielding-most-catches-career/indian-premier-league-117",
    "most_dismissals": "https://www.espncricinfo.com/records/trophy/keeping-most-dismissals-career/indian-premier-league-117",

    "highest_partnerships": "https://www.espncricinfo.com/records/trophy/fow-highest-partnerships-for-any-wicket/indian-premier-league-117"
}

# %%
result_df = pd.read_csv("result_summary.csv")
highest_totals_df = pd.read_csv("highest_totals.csv")
lowest_totals_df = pd.read_csv("lowest_totals.csv")
most_runs_df = pd.read_csv("most_runs.csv")
high_scores_df = pd.read_csv("high_scores.csv")
most_sixes_df = pd.read_csv("most_sixes.csv")
most_fifties_df = pd.read_csv("most_fifties.csv")
most_ducks_df = pd.read_csv("most_ducks.csv")
most_wickets_df = pd.read_csv("most_wickets.csv")
best_bowlings_df = pd.read_csv("best_bowling_figures.csv")
best_economy_df = pd.read_csv("best_economy_rates.csv")
best_strikes_df = pd.read_csv("best_strike_rates.csv")
most_catches_df = pd.read_csv("most_catches.csv")
most_dismissals_df = pd.read_csv("most_dismissals.csv")
highest_partnership_df = pd.read_csv("highest_partnerships.csv")

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_runs_df.isna().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
most_runs_df['Player'].unique()
# Out:
# array(['V Kohli (RCB)', 'S Dhawan (DC/DCH/MI/PBKS/SRH)',
#        'RG Sharma (DCH/MI)', 'DA Warner (DC/SRH)', 'SK Raina (CSK/GL)',
#        'MS Dhoni (CSK/RPS)', 'AB de Villiers (DC/RCB)',
#        'CH Gayle (KKR/KXIP/PBKS/RCB)',
#        'RV Uthappa (CSK/KKR/MI/PWI/RCB/RR)',
#        'KD Karthik (DC/GL/KKR/KXIP/MI/RCB)',
#        'KL Rahul (KXIP/LSG/PBKS/RCB/SRH)',
#        'AM Rahane (CSK/DC/KKR/MI/RPS/RR)', 'F du Plessis (CSK/RCB/RPS)',
#        'SV Samson (DC/RR)', 'AT Rayudu (CSK/MI)', 'G Gambhir (DC/KKR)',
#        'SR Watson (CSK/RCB/RR)', 'MK Pandey (DC/KKR/LSG/MI/PWI/RCB/SRH)',
#        'SA Yadav (KKR/MI)', 'JC Buttler (MI/RR)', 'KA Pollard (MI)',
#        'RR Pant (DC)', 'Shubman Gill (GT/KKR)', 'YK Pathan (KKR/RR/SRH)',
#        'Q de Kock (DC/LSG/MI/RCB/SRH)', 'SS Iyer (DC/KKR)',
#        'RA Jadeja (CSK/GL/Kochi/RR)', 'WP Saha (CSK/GT/KKR/KXIP/SRH)',
#        'DA Miller (GT/KXIP/RR)', 'BB McCullum (CSK/GL/KKR/Kochi/RCB)',
#        'PA Patel (CSK/DCH/Kochi/MI/RCB/SRH)',
# ...

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO         object
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df_copy = most_runs_df.infer_objects()

# %%
most_runs_df_copy.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO         object
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_runs_df.columns[0]
# Out:
# 'Player'

# %%
category_gropus = most_runs_df.groupby(by=most_runs_df.columns[0])

# %%
category_gropus

# %%
category_gropus[most_runs_df.columns[5]].mean()
# Out:
# Player
# A Badoni (LSG)                            634.0
# A Symonds (DCH/MI)                        974.0
# AB de Villiers (DC/RCB)                  5162.0
# AC Gilchrist (DCH/KXIP)                  2069.0
# AD Mathews (DC/KKR/PWI)                   724.0
#                                           ...
# WP Saha (CSK/GT/KKR/KXIP/SRH)            2934.0
# Y Venugopal Rao (DC/DCH/SRH)              985.0
# YBK Jaiswal (RR)                         1607.0
# YK Pathan (KKR/RR/SRH)                   3204.0
# Yuvraj Singh (DC/KXIP/MI/PWI/RCB/SRH)    2750.0
# Name: Runs, Length: 150, dtype: float64

# %%
category_gropus[most_runs_df.columns[5]].mean().sort_index(ascending=False)
# Out:
# Player
# Yuvraj Singh (DC/KXIP/MI/PWI/RCB/SRH)    2750.0
# YK Pathan (KKR/RR/SRH)                   3204.0
# YBK Jaiswal (RR)                         1607.0
# Y Venugopal Rao (DC/DCH/SRH)              985.0
# WP Saha (CSK/GT/KKR/KXIP/SRH)            2934.0
#                                           ...
# AD Mathews (DC/KKR/PWI)                   724.0
# AC Gilchrist (DCH/KXIP)                  2069.0
# AB de Villiers (DC/RCB)                  5162.0
# A Symonds (DCH/MI)                        974.0
# A Badoni (LSG)                            634.0
# Name: Runs, Length: 150, dtype: float64

# %%
category_gropus[most_runs_df.columns[5]].mean().sort_values(ascending=False)
# Out:
# Player
# V Kohli (RCB)                    8004.0
# S Dhawan (DC/DCH/MI/PBKS/SRH)    6769.0
# RG Sharma (DCH/MI)               6628.0
# DA Warner (DC/SRH)               6565.0
# SK Raina (CSK/GL)                5528.0
#                                   ...
# Gurkeerat Singh (KXIP/RCB)        511.0
# OA Shah (KKR/Kochi/RR)            506.0
# PC Valthaty (KXIP/RR)             505.0
# SW Billings (CSK/DC/KKR)          503.0
# RR Rossouw (DC/PBKS/RCB)          473.0
# Name: Runs, Length: 150, dtype: float64

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO         object
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df[most_runs_df.columns[4]].unique()
# Out:
# array(['37', '29', '22', '30', '95', '40', '16', '17', '50', '20', '11',
#        '19', '33', '27', '23', '12', '52', '15', '44', '6', '18', '76',
#        '24', '43', '5', '4', '9', '21', '7', '8', '26', '-', '3', '36',
#        '38', '2', '13', '10', '14', '25', '28', '34', '1'], dtype=object)

# %%
most_runs_df[most_runs_df.columns[5]].unique()
# Out:
# array([8004, 6769, 6628, 6565, 5528, 5243, 5162, 4965, 4952, 4842, 4683,
#        4642, 4571, 4419, 4348, 4217, 3874, 3850, 3594, 3582, 3412, 3284,
#        3216, 3204, 3157, 3127, 2959, 2934, 2924, 2880, 2848, 2771, 2750,
#        2728, 2661, 2644, 2636, 2619, 2525, 2485, 2484, 2477, 2427, 2385,
#        2380, 2334, 2236, 2174, 2128, 2091, 2069, 2029, 1977, 1892, 1866,
#        1802, 1769, 1706, 1695, 1687, 1653, 1647, 1607, 1589, 1560, 1559,
#        1554, 1534, 1502, 1496, 1494, 1465, 1441, 1405, 1400, 1377, 1349,
#        1329, 1326, 1322, 1243, 1208, 1173, 1162, 1156, 1153, 1139, 1115,
#        1107, 1083, 1079, 1034, 1017, 1013, 1001, 1000,  995,  993,  985,
#         974,  954,  939,  935,  924,  893,  886,  883,  880,  833,  800,
#         799,  798,  793,  772,  768,  756,  739,  730,  724,  707,  676,
#         672,  665,  663,  659,  654,  653,  634,  624,  618,  614,  604,
#         585,  577,  553,  545,  538,  536,  531,  527,  515,  514,  511,
# ...

# %%
freq_dist_NO = most_runs_df[most_runs_df.columns[4]].value_counts()

# %%
freq_dist_NO.index[0]
# Out:
# '2'

# %%
most_runs_df[most_runs_df.columns[4]].replace(to_replace=["-"],value=[np.nan],inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\3403301693.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_runs_df[most_runs_df.columns[4]].replace(to_replace=["-"],value=[np.nan],inplace=True)

# %%
most_runs_df[most_runs_df.columns[4]].unique()
# Out:
# array(['37', '29', '22', '30', '95', '40', '16', '17', '50', '20', '11',
#        '19', '33', '27', '23', '12', '52', '15', '44', '6', '18', '76',
#        '24', '43', '5', '4', '9', '21', '7', '8', '26', nan, '3', '36',
#        '38', '2', '13', '10', '14', '25', '28', '34', '1'], dtype=object)

# %%
NO_copy = most_runs_df[most_runs_df.columns[4]].fillna(value=freq_dist_NO.index[0])

# %%
NO_copy.unique()
# Out:
# array(['37', '29', '22', '30', '95', '40', '16', '17', '50', '20', '11',
#        '19', '33', '27', '23', '12', '52', '15', '44', '6', '18', '76',
#        '24', '43', '5', '4', '9', '21', '7', '8', '26', '2', '3', '36',
#        '38', '13', '10', '14', '25', '28', '34', '1'], dtype=object)

# %%
NO_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_runs_df[most_runs_df[most_runs_df.columns[4]].isna()]
# Out:
#                             Player       Span  Mat  Inns   NO  Runs   HS  \
# 53                    PP Shaw (DC)  2018-2024   79    79  NaN  1892   99
# 116  Prabhsimran Singh (KXIP/PBKS)  2019-2024   34    34  NaN   756  103
#
#        Ave    BF      SR 100  50  0   4s  6s
# 53   23.94  1283  147.46   -  14  7  238  61
# 116  22.23   517  146.22   1   3  3   78  41

# %%
most_frequent_value = most_runs_df[most_runs_df.columns[4]].mode()[0]

# %%
most_frequent_value
# Out:
# '2'

# %%
most_runs_df[most_runs_df.columns[4]].fillna(value=most_frequent_value, inplace=True)

# %%
most_runs_df[most_runs_df.columns[4]].isna().sum()
# Out:
# 0

# %%
most_runs_df[most_runs_df.columns[4]] = most_runs_df[most_runs_df.columns[4]].astype("int64")

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_runs_df[most_runs_df.columns[10]].unique()
# Out:
# array(['8', '2', '4', '1', '-', '3', '6', '7'], dtype=object)

# %%
freq_dist_100 = most_runs_df[most_runs_df.columns[10]].value_counts()

# %%
freq_dist_100.index[1]
# Out:
# '1'

# %%
most_runs_df[most_runs_df.columns[10]].replace(to_replace=["-"],value=np.nan,inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\1913548489.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_runs_df[most_runs_df.columns[10]].replace(to_replace=["-"],value=np.nan,inplace=True)

# %%
most_runs_df[most_runs_df.columns[10]].unique()
# Out:
# array(['8', '2', '4', '1', nan, '3', '6', '7'], dtype=object)

# %%
hundred_copy = most_runs_df[most_runs_df.columns[10]].fillna(value=freq_dist_100.index[1])

# %%
hundred_copy.unique()
# Out:
# array(['8', '2', '4', '1', '3', '6', '7'], dtype=object)

# %%
hundred_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_runs_df[most_runs_df[most_runs_df.columns[10]].isna()]
# Out:
#                                  Player       Span  Mat  Inns  NO  Runs   HS  \
# 5                    MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243  84*
# 8    RV Uthappa (CSK/KKR/MI/PWI/RCB/RR)  2008-2022  205   197  17  4952   88
# 9    KD Karthik (DC/GL/KKR/KXIP/MI/RCB)  2008-2024  257   234  50  4842  97*
# 12           F du Plessis (CSK/RCB/RPS)  2012-2024  145   138  11  4571   96
# 15                   G Gambhir (DC/KKR)  2008-2018  154   152  16  4217   93
# ..                                  ...        ...  ...   ...  ..   ...  ...
# 144               M Manhas (CSK/DC/PWI)  2008-2014   55    38  15   514  42*
# 145          Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511   65
# 146              OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506   76
# 148            SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503   56
# 149            RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473  82*
#
# ...

# %%
most_frequent_100 = most_runs_df[most_runs_df.columns[10]].mode()[0]

# %%
most_frequent_100
# Out:
# '1'

# %%
most_runs_df[most_runs_df.columns[10]].fillna(value=most_frequent_100, inplace=True)

# %%
most_runs_df[most_runs_df.columns[10]].isna().sum()
# Out:
# 0

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_runs_df[most_runs_df.columns[10]] = most_runs_df[most_runs_df.columns[10]].astype("int64")

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df[most_runs_df.columns[11]].unique()
# Out:
# array(['55', '51', '43', '62', '39', '24', '40', '31', '27', '22', '37',
#        '30', '25', '36', '21', '19', '16', '18', '20', '13', '23', '3',
#        '10', '11', '17', '12', '15', '14', '9', '6', '7', '1', '5', '8',
#        '4', '2', '-'], dtype=object)

# %%
freq_dist_50 = most_runs_df[most_runs_df.columns[11]].value_counts()

# %%
freq_dist_50.index[0]
# Out:
# '3'

# %%
most_runs_df[most_runs_df.columns[11]].replace(to_replace=["-"],value=np.nan,inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\2671204229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_runs_df[most_runs_df.columns[11]].replace(to_replace=["-"],value=np.nan,inplace=True)

# %%
most_runs_df[most_runs_df.columns[11]].unique()
# Out:
# array(['55', '51', '43', '62', '39', '24', '40', '31', '27', '22', '37',
#        '30', '25', '36', '21', '19', '16', '18', '20', '13', '23', '3',
#        '10', '11', '17', '12', '15', '14', '9', '6', '7', '1', '5', '8',
#        '4', '2', nan], dtype=object)

# %%
fifty_copy = most_runs_df[most_runs_df.columns[11]].fillna(value=freq_dist_50.index[0])

# %%
fifty_copy.unique()
# Out:
# array(['55', '51', '43', '62', '39', '24', '40', '31', '27', '22', '37',
#        '30', '25', '36', '21', '19', '16', '18', '20', '13', '23', '3',
#        '10', '11', '17', '12', '15', '14', '9', '6', '7', '1', '5', '8',
#        '4', '2'], dtype=object)

# %%
fifty_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_runs_df[most_runs_df[most_runs_df.columns[11]].isna()]
# Out:
#                            Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 108         STR Binny (MI/RCB/RR)  2010-2019   95    68  22   880  48*  19.13
# 118              JM Sharma (PBKS)  2022-2024   40    36   4   730  49*  22.81
# 122     AM Nayar (KXIP/MI/PWI/RR)  2008-2014   60    50  12   672  45*  17.68
# 125             TH David (MI/RCB)  2021-2024   38    35  12   659   46  28.65
# 129   PP Chawla (CSK/KKR/KXIP/MI)  2008-2024  192    92  36   624  24*  11.14
# 135             Abdul Samad (SRH)  2020-2024   50    40  10   577  37*  19.23
# 142  JP Faulkner (GL/KXIP/PWI/RR)  2011-2017   60    45  20   527   46  21.08
# 144         M Manhas (CSK/DC/PWI)  2008-2014   55    38  15   514  42*  22.34
#
#       BF      SR  100   50   0  4s  6s
# 108  683  128.84    1  NaN   7  66  35
# 118  483  151.13    1  NaN   2  53  45
# 122  577  116.46    1  NaN   3  55  20
# 125  387  170.28    1  NaN   3  38  46
# 129  563  110.83    1  NaN  16  56  20
# ...

# %%
most_frequent_50 = most_runs_df[most_runs_df.columns[11]].mode()[0]

# %%
most_frequent_50
# Out:
# '3'

# %%
most_runs_df[most_runs_df.columns[11]].fillna(value=most_frequent_50, inplace=True)

# %%
most_runs_df[most_runs_df.columns[11]].isna().sum()
# Out:
# 0

# %%
most_runs_df[most_runs_df.columns[11]] = most_runs_df[most_runs_df.columns[11]].astype("int64")

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR  100  50   0   4s   6s
# ...

# %%
most_runs_df[most_runs_df.columns[12]].unique()
# Out:
# array(['10', '11', '17', '8', '6', '18', '4', '13', '7', '14', '12', '5',
#        '9', '1', '3', '2', '15', '16', '-'], dtype=object)

# %%
freq_dist_0 = most_runs_df[most_runs_df.columns[12]].value_counts()

# %%
freq_dist_0.index[0]
# Out:
# '3'

# %%
most_runs_df[most_runs_df.columns[12]].replace(to_replace=["-"],value=np.nan,inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\1066538794.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_runs_df[most_runs_df.columns[12]].replace(to_replace=["-"],value=np.nan,inplace=True)

# %%
most_runs_df[most_runs_df.columns[12]].unique()
# Out:
# array(['10', '11', '17', '8', '6', '18', '4', '13', '7', '14', '12', '5',
#        '9', '1', '3', '2', '15', '16', nan], dtype=object)

# %%
zero_copy = most_runs_df[most_runs_df.columns[12]].fillna(value=freq_dist_0.index[0])

# %%
zero_copy.unique()
# Out:
# array(['10', '11', '17', '8', '6', '18', '4', '13', '7', '14', '12', '5',
#        '9', '1', '3', '2', '15', '16'], dtype=object)

# %%
zero_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_runs_df[most_runs_df[most_runs_df.columns[12]].isna()]
# Out:
#                            Player       Span  Mat  Inns  NO  Runs    HS  \
# 91           B Sai Sudharsan (GT)  2022-2024   25    25   3  1034   103
# 93      R Tewatia (DC/GT/KXIP/RR)  2014-2024   93    65  25  1013    53
# 99             A Symonds (DCH/MI)  2008-2011   39    36   9   974  117*
# 105                RK Singh (KKR)  2018-2024   46    40  11   893   67*
# 120              C Green (MI/RCB)  2023-2024   29    28  11   707  100*
# 131        JJ Roy (DC/GL/KKR/SRH)  2017-2023   21    21   2   614   91*
# 142  JP Faulkner (GL/KXIP/PWI/RR)  2011-2017   60    45  20   527    46
# 146        OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
#
#        Ave   BF      SR  100  50    0  4s  6s
# 91   47.00  743  139.16    1   6  NaN  95  31
# 93   25.32  752  134.70    1   1  NaN  84  47
# 99   36.07  750  129.86    1   5  NaN  74  41
# 105  30.79  623  143.33    1   4  NaN  67  46
# 120  41.58  460  153.69    1   2  NaN  62  32
# ...

# %%
most_frequent_0 = most_runs_df[most_runs_df.columns[12]].mode()[0]

# %%
most_frequent_0
# Out:
# '3'

# %%
most_runs_df[most_runs_df.columns[12]].fillna(value=most_frequent_0, inplace=True)

# %%
most_runs_df[most_runs_df.columns[12]].isna().sum()
# Out:
# 0

# %%
most_runs_df[most_runs_df.columns[12]] = most_runs_df[most_runs_df.columns[12]].astype("int64")

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 0           int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*
# ..                             ...        ...  ...   ...  ..   ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511    65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506    76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120*
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503    56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82*
#
#        Ave    BF      SR  100  50   0   4s   6s
# ...

# %%
most_runs_df[most_runs_df.columns[6]].unique()
# Out:
# array(['113*', '106*', '109*', '126', '100*', '84*', '133*', '175*', '88',
#        '97*', '132*', '105*', '96', '119', '93', '117*', '114*', '103*',
#        '124', '87*', '128*', '129', '100', '140*', '62*', '115*', '101*',
#        '158*', '81', '95', '83', '122', '106', '99', '87', '127', '91',
#        '101', '88*', '115', '89*', '108*', '75*', '89', '78*', '116*',
#        '124*', '110*', '77', '77*', '94', '66', '86', '114', '70*', '94*',
#        '109', '95*', '83*', '61', '64', '71*', '68*', '73', '93*', '104',
#        '71', '75', '69', '76*', '60', '63*', '103', '81*', '53', '74*',
#        '73*', '78', '107*', '92*', '67*', '69*', '48*', '50', '112*',
#        '92', '66*', '102', '49*', '65*', '45*', '61*', '46', '65', '59*',
#        '24*', '82*', '91*', '67', '104*', '37*', '58', '79*', '84', '54*',
#        '42*', '76', '120*', '56'], dtype=object)

# %%
most_runs_df[most_runs_df.columns[6]].isna().sum()
# Out:
# 0

# %%
most_runs_df[most_runs_df.columns[6]] = most_runs_df[most_runs_df.columns[6]].str.replace("*","",regex=False).astype("int64")

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs   HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565  126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100
# ..                             ...        ...  ...   ...  ..   ...  ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511   65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506   76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503   56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82
#
#        Ave    BF      SR  100  50   0   4s   6s
# 0    38.66  6065  131.97    8  55  10  705  272
# ...

# %%
most_runs_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int64
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 0           int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_runs_df["Start_Year"] = most_runs_df["Span"].str.split("-").str[0].astype("int64")
most_runs_df["End_Year"] = most_runs_df["Span"].str.split("-").str[1].astype("int64")
most_runs_df["Career_Span"] = most_runs_df["End_Year"] - most_runs_df["Start_Year"] + 1

# %%
most_runs_df
# Out:
#                             Player       Span  Mat  Inns  NO  Runs   HS  \
# 0                    V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106
# 2               RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 3               DA Warner (DC/SRH)  2009-2024  184   184  22  6565  126
# 4                SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100
# ..                             ...        ...  ...   ...  ..   ...  ...
# 145     Gurkeerat Singh (KXIP/RCB)  2012-2020   41    32   8   511   65
# 146         OA Shah (KKR/Kochi/RR)  2010-2013   23    22   7   506   76
# 147          PC Valthaty (KXIP/RR)  2009-2013   23    23   1   505  120
# 148       SW Billings (CSK/DC/KKR)  2016-2022   30    27   1   503   56
# 149       RR Rossouw (DC/PBKS/RCB)  2014-2024   22    22   2   473   82
#
#        Ave    BF      SR  100  50   0   4s   6s  Start_Year  End_Year  \
# ...

# %%
most_runs_df.drop(columns=most_runs_df.columns[1], inplace=True)

# %%
most_runs_df
# Out:
#                             Player  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0                    V Kohli (RCB)  252   244  37  8004  113  38.66  6065
# 1    S Dhawan (DC/DCH/MI/PBKS/SRH)  222   221  29  6769  106  35.25  5324
# 2               RG Sharma (DCH/MI)  257   252  29  6628  109  29.72  5054
# 3               DA Warner (DC/SRH)  184   184  22  6565  126  40.52  4697
# 4                SK Raina (CSK/GL)  205   200  30  5528  100  32.51  4043
# ..                             ...  ...   ...  ..   ...  ...    ...   ...
# 145     Gurkeerat Singh (KXIP/RCB)   41    32   8   511   65  21.29   422
# 146         OA Shah (KKR/Kochi/RR)   23    22   7   506   76  33.73   389
# 147          PC Valthaty (KXIP/RR)   23    23   1   505  120  22.95   418
# 148       SW Billings (CSK/DC/KKR)   30    27   1   503   56  19.34   388
# 149       RR Rossouw (DC/PBKS/RCB)   22    22   2   473   82  23.65   308
#
#          SR  100  50   0   4s   6s  Start_Year  End_Year  Career_Span
# ...

# %%
most_runs_df.dtypes
# Out:
# Player          object
# Mat              int64
# Inns             int64
# NO               int64
# Runs             int64
# HS               int64
# Ave            float64
# BF               int64
# SR             float64
# 100              int64
# 50               int64
# 0                int64
# 4s               int64
# 6s               int64
# Start_Year       int64
# End_Year         int64
# Career_Span      int64
# dtype: object

# %%
most_runs_df.isna().sum()
# Out:
# Player         0
# Mat            0
# Inns           0
# NO             0
# Runs           0
# HS             0
# Ave            0
# BF             0
# SR             0
# 100            0
# 50             0
# 0              0
# 4s             0
# 6s             0
# Start_Year     0
# End_Year       0
# Career_Span    0
# dtype: int64

# %%
most_runs_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### High Scores

# %%
high_scores_df
# Out:
#             Player  Runs Mins  Balls  4s  6s      SR      Team  Opposition  \
# 0         CH Gayle  175*  102     66  13  17  265.15       RCB  v Warriors
# 1      BB McCullum  158*    -     73  10  13  216.43       KKR       v RCB
# 2        Q de Kock  140*   97     70  10  10  200.00       LSG       v KKR
# 3   AB de Villiers  133*   82     59  19   4  225.42       RCB        v MI
# 4         KL Rahul  132*    -     69  14   7  191.30  Kings XI       v RCB
# ..             ...   ...  ...    ...  ..  ..     ...       ...         ...
# 95      JC Buttler  100*   95     58   9   4  172.41        RR       v RCB
# 96        WG Jacks  100*   50     41   5  10  243.90       RCB        v GT
# 97       YK Pathan   100    -     37   9   8  270.27        RR        v MI
# 98         V Kohli   100   98     58   9   4  172.41       RCB       v KKR
# 99      JC Buttler   100   97     68  11   5  147.05        RR        v MI
#
#           Ground   Match Date Scorecard
# ...

# %%
high_scores_df.dtypes
# Out:
# Player         object
# Runs           object
# Mins           object
# Balls           int64
# 4s              int64
# 6s              int64
# SR            float64
# Team           object
# Opposition     object
# Ground         object
# Match Date     object
# Scorecard      object
# dtype: object

# %%
high_scores_df[high_scores_df.columns[1]] = high_scores_df[high_scores_df.columns[1]].str.replace("*", "", regex=False).astype(int)

# %%
high_scores_df
# Out:
#             Player  Runs Mins  Balls  4s  6s      SR      Team  Opposition  \
# 0         CH Gayle   175  102     66  13  17  265.15       RCB  v Warriors
# 1      BB McCullum   158    -     73  10  13  216.43       KKR       v RCB
# 2        Q de Kock   140   97     70  10  10  200.00       LSG       v KKR
# 3   AB de Villiers   133   82     59  19   4  225.42       RCB        v MI
# 4         KL Rahul   132    -     69  14   7  191.30  Kings XI       v RCB
# ..             ...   ...  ...    ...  ..  ..     ...       ...         ...
# 95      JC Buttler   100   95     58   9   4  172.41        RR       v RCB
# 96        WG Jacks   100   50     41   5  10  243.90       RCB        v GT
# 97       YK Pathan   100    -     37   9   8  270.27        RR        v MI
# 98         V Kohli   100   98     58   9   4  172.41       RCB       v KKR
# 99      JC Buttler   100   97     68  11   5  147.05        RR        v MI
#
#           Ground   Match Date Scorecard
# ...

# %%
high_scores_df[high_scores_df.columns[2]].unique()
# Out:
# array(['102', '-', '97', '82', '78', '86', '95', '80', '104', '112', '84',
#        '103', '66', '76', '94', '100', '79', '89', '98', '91', '113',
#        '68', '99', '105', '88', '90', '62', '92', '85', '106', '73', '93',
#        '87', '58', '54', '74', '77', '110', '50'], dtype=object)

# %%
freq_dist_high = high_scores_df[high_scores_df.columns[2]].value_counts()

# %%
freq_dist_high.index[1]
# Out:
# '82'

# %%
high_scores_df[high_scores_df.columns[2]].replace(to_replace=["-"],value=np.nan,inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\384055080.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   high_scores_df[high_scores_df.columns[2]].replace(to_replace=["-"],value=np.nan,inplace=True)

# %%
high_scores_df[high_scores_df.columns[2]].unique()
# Out:
# array(['102', nan, '97', '82', '78', '86', '95', '80', '104', '112', '84',
#        '103', '66', '76', '94', '100', '79', '89', '98', '91', '113',
#        '68', '99', '105', '88', '90', '62', '92', '85', '106', '73', '93',
#        '87', '58', '54', '74', '77', '110', '50'], dtype=object)

# %%
high_score_copy = high_scores_df[high_scores_df.columns[2]].fillna(value=freq_dist_high.index[1])

# %%
high_score_copy.unique()
# Out:
# array(['102', '82', '97', '78', '86', '95', '80', '104', '112', '84',
#        '103', '66', '76', '94', '100', '79', '89', '98', '91', '113',
#        '68', '99', '105', '88', '90', '62', '92', '85', '106', '73', '93',
#        '87', '58', '54', '74', '77', '110', '50'], dtype=object)

# %%
high_score_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
high_scores_df[high_scores_df[high_scores_df.columns[2]].isna()]
# Out:
#               Player  Runs Mins  Balls  4s  6s      SR        Team  \
# 1        BB McCullum   158  NaN     73  10  13  216.43         KKR
# 4           KL Rahul   132  NaN     69  14   7  191.30    Kings XI
# 8            RR Pant   128  NaN     63  15   7  203.17  Daredevils
# 9            M Vijay   127  NaN     56   8  11  226.78         CSK
# 14          V Sehwag   122  NaN     58  12   8  210.34    Kings XI
# 15       PC Valthaty   120  NaN     63  19   2  190.47    Kings XI
# 16          V Sehwag   119  NaN     56  13   6  212.50  Daredevils
# 18         A Symonds   117  NaN     53  11   7  220.75    Chargers
# 19         SR Watson   117  NaN     57  11   8  205.26         CSK
# 21        MEK Hussey   116  NaN     54   8   9  214.81         CSK
# 24          SE Marsh   115  NaN     69  11   7  166.66    Kings XI
# 25     ST Jayasuriya   114  NaN     48   9  11  237.50          MI
# 26         MK Pandey   114  NaN     73  10   4  156.16         RCB
# ...

# %%
most_frequent_high_score = high_scores_df[high_scores_df.columns[2]].mode()[0]

# %%
most_frequent_high_score
# Out:
# '82'

# %%
high_scores_df[high_scores_df.columns[2]].fillna(value=most_frequent_high_score, inplace=True)

# %%
high_scores_df[high_scores_df.columns[2]].isna().sum()
# Out:
# 0

# %%
high_scores_df[high_scores_df.columns[2]] = high_scores_df[high_scores_df.columns[2]].astype("int64")

# %%
high_scores_df.dtypes
# Out:
# Player         object
# Runs            int32
# Mins            int64
# Balls           int64
# 4s              int64
# 6s              int64
# SR            float64
# Team           object
# Opposition     object
# Ground         object
# Match Date     object
# Scorecard      object
# dtype: object

# %%
high_scores_df
# Out:
#             Player  Runs  Mins  Balls  4s  6s      SR      Team  Opposition  \
# 0         CH Gayle   175   102     66  13  17  265.15       RCB  v Warriors
# 1      BB McCullum   158    82     73  10  13  216.43       KKR       v RCB
# 2        Q de Kock   140    97     70  10  10  200.00       LSG       v KKR
# 3   AB de Villiers   133    82     59  19   4  225.42       RCB        v MI
# 4         KL Rahul   132    82     69  14   7  191.30  Kings XI       v RCB
# ..             ...   ...   ...    ...  ..  ..     ...       ...         ...
# 95      JC Buttler   100    95     58   9   4  172.41        RR       v RCB
# 96        WG Jacks   100    50     41   5  10  243.90       RCB        v GT
# 97       YK Pathan   100    82     37   9   8  270.27        RR        v MI
# 98         V Kohli   100    98     58   9   4  172.41       RCB       v KKR
# 99      JC Buttler   100    97     68  11   5  147.05        RR        v MI
#
#           Ground   Match Date Scorecard
# ...

# %%
high_scores_df[high_scores_df.columns[10]] = pd.to_datetime(high_scores_df[high_scores_df.columns[10]])

# %%
high_scores_df.dtypes
# Out:
# Player                object
# Runs                   int32
# Mins                   int64
# Balls                  int64
# 4s                     int64
# 6s                     int64
# SR                   float64
# Team                  object
# Opposition            object
# Ground                object
# Match Date    datetime64[ns]
# Scorecard             object
# dtype: object

# %%
high_scores_df
# Out:
#             Player  Runs  Mins  Balls  4s  6s      SR      Team  Opposition  \
# 0         CH Gayle   175   102     66  13  17  265.15       RCB  v Warriors
# 1      BB McCullum   158    82     73  10  13  216.43       KKR       v RCB
# 2        Q de Kock   140    97     70  10  10  200.00       LSG       v KKR
# 3   AB de Villiers   133    82     59  19   4  225.42       RCB        v MI
# 4         KL Rahul   132    82     69  14   7  191.30  Kings XI       v RCB
# ..             ...   ...   ...    ...  ..  ..     ...       ...         ...
# 95      JC Buttler   100    95     58   9   4  172.41        RR       v RCB
# 96        WG Jacks   100    50     41   5  10  243.90       RCB        v GT
# 97       YK Pathan   100    82     37   9   8  270.27        RR        v MI
# 98         V Kohli   100    98     58   9   4  172.41       RCB       v KKR
# 99      JC Buttler   100    97     68  11   5  147.05        RR        v MI
#
#           Ground Match Date Scorecard
# ...

# %%
high_scores_df.drop(columns=high_scores_df.columns[11], inplace=True)

# %%
high_scores_df
# Out:
#             Player  Runs  Mins  Balls  4s  6s      SR      Team  Opposition  \
# 0         CH Gayle   175   102     66  13  17  265.15       RCB  v Warriors
# 1      BB McCullum   158    82     73  10  13  216.43       KKR       v RCB
# 2        Q de Kock   140    97     70  10  10  200.00       LSG       v KKR
# 3   AB de Villiers   133    82     59  19   4  225.42       RCB        v MI
# 4         KL Rahul   132    82     69  14   7  191.30  Kings XI       v RCB
# ..             ...   ...   ...    ...  ..  ..     ...       ...         ...
# 95      JC Buttler   100    95     58   9   4  172.41        RR       v RCB
# 96        WG Jacks   100    50     41   5  10  243.90       RCB        v GT
# 97       YK Pathan   100    82     37   9   8  270.27        RR        v MI
# 98         V Kohli   100    98     58   9   4  172.41       RCB       v KKR
# 99      JC Buttler   100    97     68  11   5  147.05        RR        v MI
#
#           Ground Match Date
# ...

# %% [markdown]
# ### Most Sixes

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs    HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175*
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84*
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133*
# ..                               ...        ...  ...   ...  ..   ...   ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75*
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114*
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83*
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110*
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665    89
#
#       Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_sixes_df[most_sixes_df.columns[6]] = most_sixes_df[most_sixes_df.columns[6]].str.replace("*", "", regex=False).astype(int)

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133
# ..                               ...        ...  ...   ...  ..   ...  ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665   89
#
#       Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_sixes_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO         object
# Runs        int64
# HS          int32
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_sixes_df[most_sixes_df.columns[4]].unique()
# Out:
# array(['16', '29', '37', '95', '40', '22', '52', '20', '19', '30', '17',
#        '33', '11', '12', '50', '44', '15', '43', '9', '5', '23', '18',
#        '6', '27', '76', '4', '8', '24', '26', '36', '7', '3', '2', '13',
#        '-', '38', '10', '21', '28', '1', '25', '14'], dtype=object)

# %%
freq_dist_NO = most_sixes_df[most_sixes_df.columns[4]].value_counts()

# %%
freq_dist_NO.index[0]
# Out:
# '2'

# %%
most_sixes_df[most_sixes_df.columns[4]].replace(to_replace="-",value=np.nan, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\2354959128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[4]].replace(to_replace="-",value=np.nan, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[4]].unique()
# Out:
# array(['16', '29', '37', '95', '40', '22', '52', '20', '19', '30', '17',
#        '33', '11', '12', '50', '44', '15', '43', '9', '5', '23', '18',
#        '6', '27', '76', '4', '8', '24', '26', '36', '7', '3', '2', '13',
#        nan, '38', '10', '21', '28', '1', '25', '14'], dtype=object)

# %%
most_sixes_copy = most_sixes_df[most_sixes_df.columns[4]].fillna(value=freq_dist_NO.index[0])

# %%
most_sixes_copy.unique()
# Out:
# array(['16', '29', '37', '95', '40', '22', '52', '20', '19', '30', '17',
#        '33', '11', '12', '50', '44', '15', '43', '9', '5', '23', '18',
#        '6', '27', '76', '4', '8', '24', '26', '36', '7', '3', '2', '13',
#        '38', '10', '21', '28', '1', '25', '14'], dtype=object)

# %%
most_sixes_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_sixes_df[most_sixes_df[most_sixes_df.columns[4]].isna()]
# Out:
#                            Player       Span  Mat  Inns   NO  Runs   HS  \
# 63                   PP Shaw (DC)  2018-2024   79    79  NaN  1892   99
# 90  Prabhsimran Singh (KXIP/PBKS)  2019-2024   34    34  NaN   756  103
#
#       Ave    BF      SR 100  50  0   4s  6s
# 63  23.94  1283  147.46   -  14  7  238  61
# 90  22.23   517  146.22   1   3  3   78  41

# %%
most_frequent_NO = most_sixes_df[most_sixes_df.columns[4]].mode()[0]

# %%
most_frequent_NO
# Out:
# '2'

# %%
most_sixes_df[most_sixes_df.columns[4]].fillna(value=most_frequent_NO, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\2803694194.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[4]].fillna(value=most_frequent_NO, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[4]].isna().sum()
# Out:
# 0

# %%
most_sixes_df[most_sixes_df.columns[4]] = most_sixes_df[most_sixes_df.columns[4]].astype("int64")

# %%
most_sixes_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int32
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133
# ..                               ...        ...  ...   ...  ..   ...  ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665   89
#
#       Ave    BF      SR 100  50   0   4s   6s
# ...

# %%
most_sixes_df[most_sixes_df.columns[10]].unique()
# Out:
# array(['6', '2', '8', '-', '3', '4', '1', '7'], dtype=object)

# %%
freq_dist_hundred = most_sixes_df[most_sixes_df.columns[10]].value_counts()

# %%
freq_dist_hundred.index[1]
# Out:
# '1'

# %%
most_sixes_df[most_sixes_df.columns[10]].replace(to_replace="-",value=np.nan, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\4099649739.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[10]].replace(to_replace="-",value=np.nan, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[10]].unique()
# Out:
# array(['6', '2', '8', nan, '3', '4', '1', '7'], dtype=object)

# %%
most_sixes_100_copy = most_sixes_df[most_sixes_df.columns[10]].fillna(value=freq_dist_hundred.index[1])

# %%
most_sixes_100_copy.unique()
# Out:
# array(['6', '2', '8', '1', '3', '4', '7'], dtype=object)

# %%
most_sixes_100_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_sixes_df[most_sixes_df[most_sixes_df.columns[10]].isna()]
# Out:
#                                          Player       Span  Mat  Inns  NO  \
# 3                            MS Dhoni (CSK/RPS)  2008-2024  264   229  95
# 6                               KA Pollard (MI)  2010-2022  189   171  52
# 7                           AD Russell (DC/KKR)  2012-2024  127   105  20
# 12           RV Uthappa (CSK/KKR/MI/PWI/RCB/RR)  2008-2022  205   197  17
# 14                   F du Plessis (CSK/RCB/RPS)  2012-2024  145   138  11
# 16           KD Karthik (DC/GL/KKR/KXIP/MI/RCB)  2008-2024  257   234  50
# 17                  GJ Maxwell (DC/KXIP/MI/RCB)  2012-2024  134   129  17
# 21        Yuvraj Singh (DC/KXIP/MI/PWI/RCB/SRH)  2008-2019  132   126  15
# 22                            HH Pandya (GT/MI)  2015-2024  137   128  40
# 24                              N Rana (KKR/MI)  2016-2024  107   101   9
# 27                 N Pooran (KXIP/LSG/PBKS/SRH)  2019-2024   76    73  18
# 29                         Ishan Kishan (GL/MI)  2016-2024  105    99   6
# ...

# %%
most_frequent_100_sixes = most_sixes_df[most_sixes_df.columns[10]].mode()[0]

# %%
most_frequent_100_sixes
# Out:
# '1'

# %%
most_sixes_df[most_sixes_df.columns[10]].fillna(value=most_frequent_100_sixes, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\1220831044.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[10]].fillna(value=most_frequent_100_sixes, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[10]].isna().sum()
# Out:
# 0

# %%
most_sixes_df[most_sixes_df.columns[10]] = most_sixes_df[most_sixes_df.columns[10]].astype("int64")

# %%
most_sixes_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int32
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50         object
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_sixes_df[most_sixes_df.columns[11]].unique()
# Out:
# array(['31', '43', '55', '24', '40', '62', '16', '11', '25', '39', '21',
#        '37', '27', '22', '19', '18', '13', '51', '10', '9', '23', '17',
#        '3', '30', '7', '20', '12', '4', '14', '6', '15', '5', '8', '1',
#        '36', '-'], dtype=object)

# %%
freq_dist_fifty = most_sixes_df[most_sixes_df.columns[11]].value_counts()

# %%
freq_dist_fifty.index[0]
# Out:
# '13'

# %%
most_sixes_df[most_sixes_df.columns[11]].replace(to_replace="-",value=np.nan, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\1045214744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[11]].replace(to_replace="-",value=np.nan, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[11]].unique()
# Out:
# array(['31', '43', '55', '24', '40', '62', '16', '11', '25', '39', '21',
#        '37', '27', '22', '19', '18', '13', '51', '10', '9', '23', '17',
#        '3', '30', '7', '20', '12', '4', '14', '6', '15', '5', '8', '1',
#        '36', nan], dtype=object)

# %%
most_sixes_50_copy = most_sixes_df[most_sixes_df.columns[11]].fillna(value=freq_dist_fifty.index[0])

# %%
most_sixes_50_copy.unique()
# Out:
# array(['31', '43', '55', '24', '40', '62', '16', '11', '25', '39', '21',
#        '37', '27', '22', '19', '18', '13', '51', '10', '9', '23', '17',
#        '3', '30', '7', '20', '12', '4', '14', '6', '15', '5', '8', '1',
#        '36'], dtype=object)

# %%
most_sixes_50_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_sixes_df[most_sixes_df[most_sixes_df.columns[11]].isna()]
# Out:
#                Player       Span  Mat  Inns  NO  Runs  HS    Ave   BF      SR  \
# 77  TH David (MI/RCB)  2021-2024   38    35  12   659  46  28.65  387  170.28
# 80   JM Sharma (PBKS)  2022-2024   40    36   4   730  49  22.81  483  151.13
#
#     100   50  0  4s  6s
# 77    1  NaN  3  38  46
# 80    1  NaN  2  53  45

# %%
most_frequent_50_sixes = most_sixes_df[most_sixes_df.columns[11]].mode()[0]

# %%
most_frequent_50_sixes
# Out:
# '13'

# %%
most_sixes_df[most_sixes_df.columns[11]].fillna(value=most_frequent_50_sixes, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\2562612660.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[11]].fillna(value=most_frequent_50_sixes, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[11]].isna().sum()
# Out:
# 0

# %%
most_sixes_df[most_sixes_df.columns[11]] = most_sixes_df[most_sixes_df.columns[11]].astype("int64")

# %%
most_sixes_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int32
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 0          object
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133
# ..                               ...        ...  ...   ...  ..   ...  ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665   89
#
#       Ave    BF      SR  100  50   0   4s   6s
# ...

# %%
most_sixes_df[most_sixes_df.columns[12]].unique()
# Out:
# array(['8', '17', '10', '6', '11', '5', '7', '4', '14', '18', '9', '13',
#        '3', '16', '2', '1', '12', '-'], dtype=object)

# %%
freq_dist_zero = most_sixes_df[most_sixes_df.columns[12]].value_counts()

# %%
freq_dist_zero.index[0]
# Out:
# '4'

# %%
most_sixes_df[most_sixes_df.columns[12]].replace(to_replace="-",value=np.nan, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\2561637822.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[12]].replace(to_replace="-",value=np.nan, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[12]].unique()
# Out:
# array(['8', '17', '10', '6', '11', '5', '7', '4', '14', '18', '9', '13',
#        '3', '16', '2', '1', '12', nan], dtype=object)

# %%
most_sixes_0_copy = most_sixes_df[most_sixes_df.columns[12]].fillna(value=freq_dist_zero.index[0])

# %%
most_sixes_0_copy.unique()
# Out:
# array(['8', '17', '10', '6', '11', '5', '7', '4', '14', '18', '9', '13',
#        '3', '16', '2', '1', '12'], dtype=object)

# %%
most_sixes_0_copy.astype("int64").dtypes
# Out:
# dtype('int64')

# %%
most_sixes_df[most_sixes_df[most_sixes_df.columns[12]].isna()]
# Out:
#                        Player       Span  Mat  Inns  NO  Runs   HS    Ave  \
# 76  R Tewatia (DC/GT/KXIP/RR)  2014-2024   93    65  25  1013   53  25.32
# 78             RK Singh (KKR)  2018-2024   46    40  11   893   67  30.79
# 91         A Symonds (DCH/MI)  2008-2011   39    36   9   974  117  36.07
#
#      BF      SR  100  50    0  4s  6s
# 76  752  134.70    1   1  NaN  84  47
# 78  623  143.33    1   4  NaN  67  46
# 91  750  129.86    1   5  NaN  74  41

# %%
most_frequent_0_sixes = most_sixes_df[most_sixes_df.columns[12]].mode()[0]

# %%
most_frequent_0_sixes
# Out:
# '3'

# %%
most_sixes_df[most_sixes_df.columns[12]].fillna(value=most_frequent_0_sixes, inplace=True)
# Out:
# C:\Users\velur\AppData\Local\Temp\ipykernel_22456\1852581486.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   most_sixes_df[most_sixes_df.columns[12]].fillna(value=most_frequent_0_sixes, inplace=True)

# %%
most_sixes_df[most_sixes_df.columns[12]].isna().sum()
# Out:
# 0

# %%
most_sixes_df[most_sixes_df.columns[12]] = most_sixes_df[most_sixes_df.columns[12]].astype("int64")

# %%
most_sixes_df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int32
# Ave       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 0           int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133
# ..                               ...        ...  ...   ...  ..   ...  ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665   89
#
#       Ave    BF      SR  100  50   0   4s   6s
# ...

# %%
most_sixes_df["Start_Year"] = most_sixes_df["Span"].str.split("-").str[0].astype("int64")
most_sixes_df["End_Year"] = most_sixes_df["Span"].str.split("-").str[1].astype("int64")
most_sixes_df["Career_Span"] = most_sixes_df["End_Year"] - most_sixes_df["Start_Year"] + 1

# %%
most_sixes_df
# Out:
#                               Player       Span  Mat  Inns  NO  Runs   HS  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  2009-2021  142   141  16  4965  175
# 1                 RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109
# 2                      V Kohli (RCB)  2008-2024  252   244  37  8004  113
# 3                 MS Dhoni (CSK/RPS)  2008-2024  264   229  95  5243   84
# 4            AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133
# ..                               ...        ...  ...   ...  ..   ...  ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)  2008-2018   98    85  26  1695   75
# 96                ST Jayasuriya (MI)  2008-2010   30    30   2   768  114
# 97          KK Nair (DC/KXIP/RCB/RR)  2013-2022   76    68   5  1496   83
# 98  DPMD Jayawardene (DC/Kochi/KXIP)  2008-2013   80    78  15  1802  110
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)  2010-2024   42    36   2   665   89
#
#       Ave    BF      SR  100  50   0   4s   6s  Start_Year  End_Year  \
# ...

# %%
most_sixes_df.drop(columns=most_sixes_df.columns[1], inplace=True)

# %%
most_sixes_df
# Out:
#                               Player  Mat  Inns  NO  Runs   HS    Ave    BF  \
# 0       CH Gayle (KKR/KXIP/PBKS/RCB)  142   141  16  4965  175  39.72  3333
# 1                 RG Sharma (DCH/MI)  257   252  29  6628  109  29.72  5054
# 2                      V Kohli (RCB)  252   244  37  8004  113  38.66  6065
# 3                 MS Dhoni (CSK/RPS)  264   229  95  5243   84  39.12  3812
# 4            AB de Villiers (DC/RCB)  184   170  40  5162  133  39.70  3403
# ..                               ...  ...   ...  ..   ...  ...    ...   ...
# 95       MK Tiwary (DC/KKR/KXIP/RPS)   98    85  26  1695   75  28.72  1449
# 96                ST Jayasuriya (MI)   30    30   2   768  114  27.42   532
# 97          KK Nair (DC/KXIP/RCB/RR)   76    68   5  1496   83  23.74  1171
# 98  DPMD Jayawardene (DC/Kochi/KXIP)   80    78  15  1802  110  28.60  1462
# 99     MR Marsh (DC/DCH/PWI/RPS/SRH)   42    36   2   665   89  19.55   521
#
# ...

# %% [markdown]
# ### Most Fifties

# %%
most_fifties_df
# Out:
#                                 Player       Span  Mat  Inns  NO  Runs    HS  \
# 0                   DA Warner (DC/SRH)  2009-2024  184   184  22  6565   126
# 1                        V Kohli (RCB)  2008-2024  252   244  37  8004  113*
# 2        S Dhawan (DC/DCH/MI/PBKS/SRH)  2008-2024  222   221  29  6769  106*
# 3                   RG Sharma (DCH/MI)  2008-2024  257   252  29  6628  109*
# 4              AB de Villiers (DC/RCB)  2008-2021  184   170  40  5162  133*
# ..                                 ...        ...  ...   ...  ..   ...   ...
# 95           SM Curran (CSK/KXIP/PBKS)  2019-2024   59    48  13   883   63*
# 96  MC Henriques (DC/KKR/PBKS/RCB/SRH)  2009-2021   62    54  18  1000   74*
# 97            DJ Hussey (CSK/KKR/KXIP)  2008-2014   64    61  12  1322    71
# 98       EJG Morgan (KKR/KXIP/RCB/SRH)  2010-2021   83    75  13  1405   68*
# 99                DJ Bravo (CSK/GL/MI)  2008-2022  161   113  44  1560   70*
#
# ...

# %%
most_fifties_df.isna().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 50+       0
# 0         0
# 4s        0
# 6s        0
# dtype: int64
